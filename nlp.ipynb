# %% [markdown]
# # Datahack 2022 Advance Track

# %%
# load packages 
import os 
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.style.use('ggplot')

# %%
# import files 
# %load_ext autoreload 
# %autoreload 2

from src.data_ingestion import * 
from src.visualization import * 
from src.feature_engineering import *
from src.model_train import * 
from src.model_eval import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# specify paths

# %%
# load data 
train_data = read_train()
test_data = read_test()
train_data.head()
# Out:
#                                             Sentence Sentiment
# 0  According to the Finnish-Russian Chamber of Co...   neutral
# 1  The Swedish buyout firm has sold its remaining...   neutral
# 2    $SPY wouldn't be surprised to see a green close  positive
# 3  Shell's $70 Billion BG Deal Meets Shareholder ...  negative
# 4  SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANG...  negative

# %% [markdown]
# ## Exploratory Analysis

# %%
# visualize 
visualize_sentiment_proportion(train_data)

# %%
# sentiment scores 
sentiment_scores_by_sentiment('neg')
sentiment_scores_by_sentiment('pos')
sentiment_scores_by_sentiment('neu')
sentiment_scores_by_sentiment('compound')

# %% [markdown]
# ## Feature Engineering

# %%
# sentiment scores
train_data_sentiments = sentiment_scores_embeddings(train_data)
test_data_sentiments = sentiment_scores_embeddings(test_data)

# save to file 
save_dense_embeddings(train_data_sentiments, 'train_sentiment_scores')
save_dense_embeddings(test_data_sentiments, 'test_sentiment_scores')

# %%
# common words 
train_unigram_embeddings = common_words_embeddings(train_data)

# %%
train_unigram_embeddings.sum(axis=1)
